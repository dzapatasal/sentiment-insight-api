# %% [markdown]
# # 📓 Bitácora 02: Forjando el Cerebro de G68
#
# Aquí es donde los datos se convierten en conocimiento. Aplicamos técnicas de procesamiento de lenguaje natural (NLP) y entrenamos nuestro modelo base.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import classification_report, confusion_matrix
import joblib

df = pd.read_csv('../data/processed/sentiment_curated_v1.csv')
X = df['review_text'].astype(str)
y = df['label'] # 1: Pos, 3: Neu, 0: Neg

# %% [markdown]
# ### 1. Vectorización TF-IDF (El Mapa de Palabras)
# Transformamos el texto en números dándole más peso a las palabras que realmente diferencian una reseña de otra (ignoriando las stopwords comunes).

# %%
vectorizer = TfidfVectorizer(max_features=5000, ngram_range=(1, 2))
X_vec = vectorizer.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_vec, y, test_size=0.2, random_state=42)
print("✅ Cuerpo de conocimientos (vocabulario) construido.")
# Out:
# ✅ Cuerpo de conocimientos (vocabulario) construido.

# %% [markdown]
# ### 2. Entrenamiento: El Modelo LinearSVC
# Elegimos LinearSVC por su excelente balance entre velocidad de respuesta y precisión en clasificación de texto. Calibramos el modelo para obtener probabilidades reales.

# %%
base_svc = LinearSVC(C=1.0, random_state=42)
model = CalibratedClassifierCV(base_svc)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("--- Reporte de Clasificación ---")
print(classification_report(y_test, y_pred))
# Out:
# c:\ALURA - ONE\1. CIENCIA DE DATOS\HACKATHON\sentiment-api-G68\.venv\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\ALURA - ONE\1. CIENCIA DE DATOS\HACKATHON\sentiment-api-G68\.venv\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# c:\ALURA - ONE\1. CIENCIA DE DATOS\HACKATHON\sentiment-api-G68\.venv\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# ...

# %% [markdown]
# ### 3. Persistencia
# Exportamos el cerebro para que el microservicio pueda usarlo en producción.

# %%
joblib.dump(model, '../data/models/sentiment_model.pkl')
joblib.dump(vectorizer, '../data/models/tfidf_vectorizer.pkl')
print("✅ Cerebro exportado exitosamente.")
# Out:
# ✅ Cerebro exportado exitosamente.
